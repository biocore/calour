# %%
# %matplotlib notebook
import calour as ca

# %% [markdown]
# # Simple Cases

# %%
a = ca.read_amplicon('../calour/tests/data/test2.biom', '../calour/tests/data/test2.sample', feature_metadata_file='../calour/tests/data/test2.feature', min_reads=100, normalize=1000)

b = a.plot(sample_field='group', feature_field='taxonomy', 
           bary_fields=['oxygen'], barx_fields=['group', 'categorical'], barx_label_kwargs={'color': 'b'},
           gui='jupyter', title='simple figure');
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# The installed widget Javascript is the wrong version. It must satisfy the semver range ~2.1.4.
# The installed widget Javascript is the wrong version. It must satisfy the semver range ~2.1.4.
# The installed widget Javascript is the wrong version. It must satisfy the semver range ~2.1.4.
# The installed widget Javascript is the wrong version. It must satisfy the semver range ~2.1.4.
# The installed widget Javascript is the wrong version. It must satisfy the semver range ~2.1.4.
# The installed widget Javascript is the wrong version. It must satisfy the semver range ~2.1.4.
